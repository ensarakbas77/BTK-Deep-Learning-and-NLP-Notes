# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series

# %%
my_dict = {"Kevin":19, "George":45, "Steven":76}
pd.Series(my_dict)
# Out:
# Kevin     19
# George    45
# Steven    76
# dtype: int64

# %%
ages = [19,45,76]
names = ["Kevin", "George", "Steven"]

pd.Series(data=ages, index=names)
# Out:
# Kevin     19
# George    45
# Steven    76
# dtype: int64

# %%
np_arr = np.array([19,45,76])
pd.Series(np_arr, names)
# Out:
# Kevin     19
# George    45
# Steven    76
# dtype: int64

# %%
score1 = pd.Series(data=[10,2,5], index=["K1","K2","K3"])
score2 = pd.Series(data=[11,6,8], index=["K1","K2","K3"])

# %%
total_score = score1 + score2
print(total_score)
print()
print(total_score["K2"])
# Out:
# K1    21
# K2     8
# K3    13
# dtype: int64
#
# 8

# %% [markdown]
# ## DataFrame

# %%
data = np.random.randn(4,3)
data
# Out:
# array([[ 0.22651008,  1.22751232, -0.0781857 ],
#        [ 0.75999215,  0.64938266, -0.69551747],
#        [-0.86739777, -1.89064463, -0.56809678],
#        [ 0.04946857,  1.57808351, -0.54718039]])

# %%
df = pd.DataFrame(data)
df
# Out:
#           0         1         2
# 0  0.226510  1.227512 -0.078186
# 1  0.759992  0.649383 -0.695517
# 2 -0.867398 -1.890645 -0.568097
# 3  0.049469  1.578084 -0.547180

# %%
df[0] # kolonları getirir
# Out:
# 0    0.226510
# 1    0.759992
# 2   -0.867398
# 3    0.049469
# Name: 0, dtype: float64

# %%
new_df = pd.DataFrame(data, index=["A0", "A1", "A2", "A3"], columns=["salary", "age", "working_hours"])
new_df
# Out:
#       salary       age  working_hours
# A0  0.226510  1.227512      -0.078186
# A1  0.759992  0.649383      -0.695517
# A2 -0.867398 -1.890645      -0.568097
# A3  0.049469  1.578084      -0.547180

# %%
new_df[["salary", "age"]]
# Out:
#       salary       age
# A0  0.226510  1.227512
# A1  0.759992  0.649383
# A2 -0.867398 -1.890645
# A3  0.049469  1.578084

# %%
# location
new_df.loc["A0"]
# Out:
# salary           0.226510
# age              1.227512
# working_hours   -0.078186
# Name: A0, dtype: float64

# %%
# index bazlı location
new_df.iloc[0]
# Out:
# salary           0.226510
# age              1.227512
# working_hours   -0.078186
# Name: A0, dtype: float64

# %%
new_df["retirement_age"] = new_df["age"] * 2
new_df
# Out:
#       salary       age  working_hours  retirement_age
# A0  0.226510  1.227512      -0.078186        2.455025
# A1  0.759992  0.649383      -0.695517        1.298765
# A2 -0.867398 -1.890645      -0.568097       -3.781289
# A3  0.049469  1.578084      -0.547180        3.156167

# %%
new_df.drop("retirement_age", axis=1) # axis=1 -> sütun
# Out:
#       salary       age  working_hours
# A0  0.226510  1.227512      -0.078186
# A1  0.759992  0.649383      -0.695517
# A2 -0.867398 -1.890645      -0.568097
# A3  0.049469  1.578084      -0.547180

# %%
new_df.drop("A3", axis=0) # axis=0 -> satır
# Out:
#       salary       age  working_hours  retirement_age
# A0  0.226510  1.227512      -0.078186        2.455025
# A1  0.759992  0.649383      -0.695517        1.298765
# A2 -0.867398 -1.890645      -0.568097       -3.781289

# %%
# Sildiklerimiz ugulanmadı. Değişikliklerimizin df içerisinde uygulanması için;
# df = new_df.drop("retirement_age", axis = 1) yada,
new_df.drop("retirement_age", axis = 1, inplace=True) # yapabiliriz

# %%
new_df
# Out:
#       salary       age  working_hours
# A0  0.226510  1.227512      -0.078186
# A1  0.759992  0.649383      -0.695517
# A2 -0.867398 -1.890645      -0.568097
# A3  0.049469  1.578084      -0.547180

# %%
print(new_df.loc["A0"]["age"])
print()
print(new_df.loc["A0", "age"])
# Out:
# 1.2275123215454535
#
# 1.2275123215454535

# %%
new_df < 0
# Out:
#     salary    age  working_hours
# A0   False  False           True
# A1   False  False           True
# A2    True   True           True
# A3   False  False           True

# %%
new_df[new_df < 0]
# Out:
#       salary       age  working_hours
# A0       NaN       NaN      -0.078186
# A1       NaN       NaN      -0.695517
# A2 -0.867398 -1.890645      -0.568097
# A3       NaN       NaN      -0.547180

# %%
new_df[new_df["salary"] > 0]
# Out:
#       salary       age  working_hours
# A0  0.226510  1.227512      -0.078186
# A1  0.759992  0.649383      -0.695517
# A3  0.049469  1.578084      -0.547180

# %%
new_df.reset_index()
# Out:
#   index    salary       age  working_hours
# 0    A0  0.226510  1.227512      -0.078186
# 1    A1  0.759992  0.649383      -0.695517
# 2    A2 -0.867398 -1.890645      -0.568097
# 3    A3  0.049469  1.578084      -0.547180

# %%
new_index_list = ["a0", "a1", "a2", "a3"]
new_df["new_index"] = new_index_list

# %%
new_df
# Out:
#       salary       age  working_hours new_index
# A0  0.226510  1.227512      -0.078186        a0
# A1  0.759992  0.649383      -0.695517        a1
# A2 -0.867398 -1.890645      -0.568097        a2
# A3  0.049469  1.578084      -0.547180        a3

# %%
new_df = new_df.set_index("new_index")

# %%
new_df
# Out:
#              salary       age  working_hours
# new_index
# a0         0.226510  1.227512      -0.078186
# a1         0.759992  0.649383      -0.695517
# a2        -0.867398 -1.890645      -0.568097
# a3         0.049469  1.578084      -0.547180

# %%
dıs_index = ["A","A","A","B","B","B"]
ic_index = ["a1","a2","a3","b1","b2","b3"]

birlesmis_index = list(zip(dıs_index, ic_index))
birlesmis_index
# Out:
# [('A', 'a1'), ('A', 'a2'), ('A', 'a3'), ('B', 'b1'), ('B', 'b2'), ('B', 'b3')]

# %%
multiIndex = pd.MultiIndex.from_tuples(birlesmis_index)
multiIndex
# Out:
# MultiIndex([('A', 'a1'),
#             ('A', 'a2'),
#             ('A', 'a3'),
#             ('B', 'b1'),
#             ('B', 'b2'),
#             ('B', 'b3')],
#            )

# %%
my_list = [[40,6],[24,2],[52,10],[15,1],[63,15],[35,5]]
my_df = pd.DataFrame(my_list, index=multiIndex, columns=["Age", "Experience"])
my_df
# Out:
#       Age  Experience
# A a1   40           6
#   a2   24           2
#   a3   52          10
# B b1   15           1
#   b2   63          15
#   b3   35           5

# %% [markdown]
# ## Operations

# %%
weather_dict = {
    "Istanbul": [30,29,np.nan,33],
    "Ankara": [np.nan,np.nan,25,23],
    "Izmır": [40,39,38,37],
    "Kocaeli": [np.nan,28,29,30]
}

weather_df = pd.DataFrame(weather_dict)
weather_df
# Out:
#    Istanbul  Ankara  Izmır  Kocaeli
# 0      30.0     NaN     40      NaN
# 1      29.0     NaN     39     28.0
# 2       NaN    25.0     38     29.0
# 3      33.0    23.0     37     30.0

# %%
# Eksik veriler ile çalışmak
weather_df.dropna()
# Out:
#    Istanbul  Ankara  Izmır  Kocaeli
# 3      33.0    23.0     37     30.0

# %%
weather_df.dropna(axis=1)
# Out:
#    Izmır
# 0     40
# 1     39
# 2     38
# 3     37

# %%
weather_df.dropna(axis = 1, thresh=3) # sütuna bakar, 2 den fazla NaN olanı siler
# Out:
#    Istanbul  Izmır  Kocaeli
# 0      30.0     40      NaN
# 1      29.0     39     28.0
# 2       NaN     38     29.0
# 3      33.0     37     30.0

# %%
weather_df.fillna(20)
# Out:
#    Istanbul  Ankara  Izmır  Kocaeli
# 0      30.0    20.0     40     20.0
# 1      29.0    20.0     39     28.0
# 2      20.0    25.0     38     29.0
# 3      33.0    23.0     37     30.0

# %% [markdown]
# ### Groupby

# %%
maas_dict = {
    "department": ["Yazılım","Yazılım","Pazarlama","Hukuk","Hukuk","Pazarlama"],
    "name": ["Ahmet","Ali","Ayşe","Hakan","Kemal","Fatma"],
    "salary": [200,300,100,150,200,150]
}

maas_df = pd.DataFrame(maas_dict)
maas_df
# Out:
#   department   name  salary
# 0    Yazılım  Ahmet     200
# 1    Yazılım    Ali     300
# 2  Pazarlama   Ayşe     100
# 3      Hukuk  Hakan     150
# 4      Hukuk  Kemal     200
# 5  Pazarlama  Fatma     150

# %%
group = maas_df.groupby("department")

# %%
group.count()
# Out:
#             name  salary
# department
# Hukuk          2       2
# Pazarlama      2       2
# Yazılım        2       2

# %%
group.max()
# Out:
#              name  salary
# department
# Hukuk       Kemal     200
# Pazarlama   Fatma     150
# Yazılım       Ali     300

# %%
group.mean(numeric_only=True)
# Out:
#             salary
# department
# Hukuk        175.0
# Pazarlama    125.0
# Yazılım      250.0

# %%
group.describe()
# Out:
#            salary
#             count   mean        std    min    25%    50%    75%    max
# department
# Hukuk         2.0  175.0  35.355339  150.0  162.5  175.0  187.5  200.0
# Pazarlama     2.0  125.0  35.355339  100.0  112.5  125.0  137.5  150.0
# Yazılım       2.0  250.0  70.710678  200.0  225.0  250.0  275.0  300.0

# %% [markdown]
# ### Concat

# %%
dict_1 = {
    "Isım": ["Ahmet", "Mehmet","Zeynep","Veli"],
    "Spor": ["Koşu", "Yüzme", "Koşu","Basketbol"],
    "Kalori" : [100,200,300,400]
}

df_1 = pd.DataFrame(dict_1, index = [0,1,2,3])

dict_2 = {
    "Isım": ["Mahmut", "Kerim", "Ayşe", "Ozan"],
    "Spor": ["Futbol", "Basketbol", "Tenis", "Voleybol"],
    "Kalori": [200,300,100,200]
}

df_2 = pd.DataFrame(dict_2, index = [4,5,6,7])

# %%
df_1
# Out:
#      Isım       Spor  Kalori
# 0   Ahmet       Koşu     100
# 1  Mehmet      Yüzme     200
# 2  Zeynep       Koşu     300
# 3    Veli  Basketbol     400

# %%
df_2
# Out:
#      Isım       Spor  Kalori
# 4  Mahmut     Futbol     200
# 5   Kerim  Basketbol     300
# 6    Ayşe      Tenis     100
# 7    Ozan   Voleybol     200

# %%
# concatenation
df_concat = pd.concat(objs=[df_1, df_2])
df_concat
# Out:
#      Isım       Spor  Kalori
# 0   Ahmet       Koşu     100
# 1  Mehmet      Yüzme     200
# 2  Zeynep       Koşu     300
# 3    Veli  Basketbol     400
# 4  Mahmut     Futbol     200
# 5   Kerim  Basketbol     300
# 6    Ayşe      Tenis     100
# 7    Ozan   Voleybol     200

# %% [markdown]
# ### merge

# %%
dict_1 = {
    "Isım": ["a","b","c","d"],
    "Spor": ["top","koş","yüz","atla"]
}

dict_2 = {
    "Isım": ["a","b","c","d"],
    "Kalori": [5,10,15,20]
}

df1 = pd.DataFrame(dict_1)
df2 = pd.DataFrame(dict_2)

# %%
df1
# Out:
#   Isım  Spor
# 0    a   top
# 1    b   koş
# 2    c   yüz
# 3    d  atla

# %%
df2
# Out:
#   Isım  Kalori
# 0    a       5
# 1    b      10
# 2    c      15
# 3    d      20

# %%
merge_df = pd.merge(df1, df2, on="Isım")
merge_df
# Out:
#   Isım  Spor  Kalori
# 0    a   top       5
# 1    b   koş      10
# 2    c   yüz      15
# 3    d  atla      20

# %%
maas_df["department"].unique()
# Out:
# array(['Yazılım', 'Pazarlama', 'Hukuk'], dtype=object)

# %%
maas_df["department"].nunique()
# Out:
# 3

# %%
maas_df["department"].value_counts()
# Out:
# department
# Yazılım      2
# Pazarlama    2
# Hukuk        2
# Name: count, dtype: int64

# %%
maas_df.salary
# Out:
# 0    200
# 1    300
# 2    100
# 3    150
# 4    200
# 5    150
# Name: salary, dtype: int64

# %%
def func(maas):
    return maas * 0.66

# apply
maas_df["salary"].apply(func)
# Out:
# 0    132.0
# 1    198.0
# 2     66.0
# 3     99.0
# 4    132.0
# 5     99.0
# Name: salary, dtype: float64

# %%
maas_df.isnull().sum()
# Out:
# department    0
# name          0
# salary        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      float64
#  1   1       4 non-null      float64
#  2   2       4 non-null      float64
# dtypes: float64(3)
# memory usage: 228.0 bytes

# %%
maas_df.pivot_table(values="salary", index=["department", "name"])
# Out:
#                   salary
# department name
# Hukuk      Hakan   150.0
#            Kemal   200.0
# Pazarlama  Ayşe    100.0
#            Fatma   150.0
# Yazılım    Ahmet   200.0
#            Ali     300.0

# %%
# excel ile çalışmak
#pd.read_csv("")
#pd.read_excel("")

# kaydetme
#df.to_excel("a.xlsx")
#df.to_csv(a.csv)
